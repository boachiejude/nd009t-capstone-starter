# %% [markdown]
# # Inventory Monitoring at Distribution Centres
# Train a model to count the number of items in a box using Amazon SageMaker.
#
# **TODO**: Give a helpful introduction to what this notebook is for. Remember that comments, explanations and good documentation make your project informative and professional.
#
# **Note:** This notebook has a bunch of code and markdown cells with TODOs that you have to complete. These are meant to be helpful guidelines for you to finish your project while meeting the requirements in the project rubrics. Feel free to change the order of the TODO's and/or use more than one cell to complete all the tasks.

# %%
# TODO: Install any packages that you might need

# %%
import os
import json
import boto3
import tqdm
import sagemaker

from sagemaker.pytorch import PyTorch

# %% [markdown]
# ## Data Preparation
# **TODO:** Run the cell below to download the data.
#
# The cell below creates a folder called `train_data`, downloads training data and arranges it in subfolders. Each of these subfolders contain images where the number of objects is equal to the name of the folder. For instance, all images in folder `1` has images with 1 object in them. Images are not divided into training, testing or validation sets. If you feel like the number of samples are not enough, you can always download more data (instructions for that can be found [here](https://registry.opendata.aws/amazon-bin-imagery/)). However, we are not acessing you on the accuracy of your final trained model, but how you create your machine learning engineering pipeline.

# %%
def download_and_arrange_data():
    s3_client = boto3.client('s3')

    with open('file_list.json', 'r') as f:
        d=json.load(f)

    for k, v in d.items():
        print(f"Downloading Images with {k} objects")
        directory=os.path.join('train_data', k)
        if not os.path.exists(directory):
            os.makedirs(directory)
        for file_path in tqdm(v):
            file_name=os.path.basename(file_path).split('.')[0]+'.jpg'
            s3_client.download_file('aft-vbi-pds', os.path.join('bin-images', file_name),
                             os.path.join(directory, file_name))

download_and_arrange_data()

# %% [markdown]
# ## Dataset
# **TODO:** Explain what dataset you are using for this project. Give a small overview of the classes, class distributions etc that can help anyone not familiar with the dataset get a better understanding of it. You can find more information about the data [here](https://registry.opendata.aws/amazon-bin-imagery/).

# %%
#TODO: Perform any data cleaning or data preprocessing

# Split the data into train and test
from os import listdir, rename, mkdir
from os.path import isfile, join

mkdir("test_data")

for i in range(0, 6):
    mypath = f'train_data/{i}'
    files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    num_test_objects = int(len(files) * 0.2)
    test_objects = files[-num_test_objects:]
    
    mkdir(f"test_data/{i}")

    for o in test_objects:
        rename(f"train_data/{i}/{o}", f"test_data/{i}/{o}")

# %%
#TODO: Upload the data to AWS S3
# !aws s3 cp train_data_v2 s3://proj-5/train_data_v2 --recursive
# !aws s3 cp test_data_v2 s3://proj-5/train_data_v2 --recursive

# %% [markdown]
# ## Model Training
# **TODO:** This is the part where you can train a model. The type or architecture of the model you use is not important.
#
# **Note:** You will need to use the `train.py` script to train your model.

# %%
#TODO: Declare your model training hyperparameter.
hyperparameters = {
    "batch-size": "32",
    "lr": "0.001",
}

# %%
#TODO: Create your training estimator
role = sagemaker.get_execution_role()

estimator = PyTorch(
    entry_point='train.py',
    base_job_name='mn2',
    role=role,
    instance_count=1,
    instance_type='ml.c4.2xlarge',
    framework_version='1.4.0',
    py_version='py3',
    hyperparameters=hyperparameters,
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
# !python testing.py
# Out:
# 2023-04-15 12:33:42,118 | [INFO] Creating model
# 2023-04-15 12:33:42,595 | [INFO] Creating loss function and optimizer
# 2023-04-15 12:33:42,595 | [INFO] Creating data loaders
# 2023-04-15 12:33:42,625 | [INFO] Starting training
# 2023-04-15 12:33:42,626 | [INFO] Epoch 1 of 14
# 2023-04-15 12:33:42,626 | [INFO] Testing
# Distinct labels in test_loader: {0, 1, 2, 3, 4}
# before
# 1

# %%
# TODO: Fit your estimator
estimator.fit({"train": "s3://proj-5/train_data/", "test": "s3://proj-5/test_data/"}, wait=True)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: mn2-2023-04-15-23-26-02-978
# 2023-04-15 23:26:03 Starting - Starting the training job...
# 2023-04-15 23:26:19 Starting - Preparing the instances for training......
# 2023-04-15 23:27:21 Downloading - Downloading input data......
# 2023-04-15 23:28:13 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-15 23:28:22,855 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-15 23:28:22,858 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:22,869 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-15 23:28:22,871 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-15 23:28:23,019 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-15 23:28:23,020 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-15 23:28:23,020 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-15 23:28:23,020 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpi90phz85/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6469 sha256=380e2adb7c52c6e1b4a896c5811ae887808edcddba8a68a090310152ac450b5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7sakzqxe/wheels/bc/5e/33/69f244645ed4a82bc93325b78d9c182da23edab75b6d8a01e7
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2023-04-15 23:28:25,067 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,081 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,093 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,104 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "lr": "0.001"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "mn2-2023-04-15-23-26-02-978",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c4.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c4.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","lr":"0.001"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":"32","lr":"0.001"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mn2-2023-04-15-23-26-02-978","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch-size","32","--lr","0.001"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH-SIZE=32
# SM_HP_LR=0.001
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 train.py --batch-size 32 --lr 0.001
# Parsing arguments
# Creating model
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-15 23:28:23,590 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-15 23:28:23,594 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:23,605 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-15 23:28:23,608 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-15 23:28:23,771 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2023-04-15 23:28:23,771 sagemaker-containers INFO     Generating setup.cfg
# 2023-04-15 23:28:23,772 sagemaker-containers INFO     Generating MANIFEST.in
# 2023-04-15 23:28:23,772 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpxwru7lt7/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6469 sha256=7ee59e239b75532114aeea2ca6ae66e22af98fef9e39ba8d411b38393101f8fa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g57a_fyn/wheels/82/ae/b7/05dfd16646326541f50863225e882fc5cb7fb3d30907c4c8a4
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# Creating loss function and optimizer
# Creating data loaders
# Checking labels in train_loader
# 2023-04-15 23:28:25,852 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,866 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,878 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2023-04-15 23:28:25,889 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "lr": "0.001"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "mn2-2023-04-15-23-26-02-978",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.c4.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c4.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","lr":"0.001"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":"32","lr":"0.001"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"mn2-2023-04-15-23-26-02-978","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-840824336874/mn2-2023-04-15-23-26-02-978/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.c4.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c4.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch-size","32","--lr","0.001"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH-SIZE=32
# SM_HP_LR=0.001
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 train.py --batch-size 32 --lr 0.001
# Parsing arguments
# Creating model
# Creating loss function and optimizer
# Creating data loaders
# Checking labels in train_loader
# Distinct labels in train_loader: {0, 1, 2, 3, 4}
# Starting training
# Epoch 1
# [2023-04-15 23:29:28.974 algo-1:50 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-15 23:29:28.974 algo-1:50 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-15 23:29:28.974 algo-1:50 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-15 23:29:28.974 algo-1:50 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-15 23:29:28.976 algo-1:50 INFO hook.py:382] Monitoring the collections: losses
# [2023-04-15 23:29:28.976 algo-1:50 INFO hook.py:443] Hook is writing from the hook with pid: 50
# Distinct labels in train_loader: {0, 1, 2, 3, 4}
# Starting training
# Epoch 1
# Trained 32 of 10441 images
# Trained 64 of 10441 images
# [2023-04-15 23:29:29.848 algo-2:50 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-15 23:29:29.848 algo-2:50 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-15 23:29:29.849 algo-2:50 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2023-04-15 23:29:29.849 algo-2:50 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-15 23:29:29.850 algo-2:50 INFO hook.py:382] Monitoring the collections: losses
# [2023-04-15 23:29:29.850 algo-2:50 INFO hook.py:443] Hook is writing from the hook with pid: 50
# Trained 32 of 10441 images
# Trained 96 of 10441 images
# Trained 64 of 10441 images
# Trained 128 of 10441 images
# Trained 96 of 10441 images
# Trained 160 of 10441 images
# Trained 128 of 10441 images
# Trained 192 of 10441 images
# Trained 224 of 10441 images
# Trained 256 of 10441 images
# Trained 288 of 10441 images
# Trained 320 of 10441 images
# Trained 160 of 10441 images
# Trained 192 of 10441 images
# Trained 224 of 10441 images
# Trained 256 of 10441 images
# Trained 288 of 10441 images
# Trained 352 of 10441 images
# Trained 320 of 10441 images
# Trained 384 of 10441 images
# Trained 352 of 10441 images
# Trained 416 of 10441 images
# Trained 384 of 10441 images
# Trained 448 of 10441 images
# Trained 416 of 10441 images
# Trained 480 of 10441 images
# Trained 512 of 10441 images
# Trained 448 of 10441 images
# Trained 480 of 10441 images
# Trained 544 of 10441 images
# Trained 512 of 10441 images
# Trained 576 of 10441 images
# Trained 544 of 10441 images
# Trained 608 of 10441 images
# Trained 576 of 10441 images
# Trained 640 of 10441 images
# Trained 608 of 10441 images
# Trained 672 of 10441 images
# Trained 704 of 10441 images
# Trained 640 of 10441 images
# Trained 672 of 10441 images
# Trained 704 of 10441 images
# Trained 736 of 10441 images
# Trained 768 of 10441 images
# Trained 736 of 10441 images
# Trained 800 of 10441 images
# Trained 768 of 10441 images
# Trained 832 of 10441 images
# Trained 864 of 10441 images
# Trained 800 of 10441 images
# Trained 896 of 10441 images
# Trained 832 of 10441 images
# Trained 864 of 10441 images
# Trained 928 of 10441 images
# Trained 896 of 10441 images
# Trained 960 of 10441 images
# Trained 928 of 10441 images
# Trained 992 of 10441 images
# Trained 960 of 10441 images
# Trained 1024 of 10441 images
# Trained 1056 of 10441 images
# Trained 992 of 10441 images
# Trained 1088 of 10441 images
# Trained 1024 of 10441 images
# Trained 1056 of 10441 images
# Trained 1088 of 10441 images
# Trained 1120 of 10441 images
# Trained 1152 of 10441 images
# Trained 1120 of 10441 images
# Trained 1184 of 10441 images
# Trained 1152 of 10441 images
# Trained 1216 of 10441 images
# Trained 1184 of 10441 images
# Trained 1248 of 10441 images
# Trained 1216 of 10441 images
# Trained 1280 of 10441 images
# Trained 1248 of 10441 images
# Trained 1312 of 10441 images
# Trained 1280 of 10441 images
# Trained 1344 of 10441 images
# Trained 1376 of 10441 images
# Trained 1312 of 10441 images
# Trained 1408 of 10441 images
# Trained 1344 of 10441 images
# Trained 1376 of 10441 images
# Trained 1440 of 10441 images
# Trained 1408 of 10441 images
# Trained 1440 of 10441 images
# Trained 1472 of 10441 images
# Trained 1504 of 10441 images
# Trained 1472 of 10441 images
# Trained 1536 of 10441 images
# Trained 1568 of 10441 images
# Trained 1504 of 10441 images
# Trained 1600 of 10441 images
# Trained 1536 of 10441 images
# Trained 1568 of 10441 images
# Trained 1632 of 10441 images
# Trained 1600 of 10441 images
# Trained 1664 of 10441 images
# Trained 1632 of 10441 images
# Trained 1696 of 10441 images
# Trained 1664 of 10441 images
# Trained 1728 of 10441 images
# Trained 1696 of 10441 images
# Trained 1760 of 10441 images
# Trained 1792 of 10441 images
# Trained 1728 of 10441 images
# Trained 1760 of 10441 images
# Trained 1824 of 10441 images
# Trained 1792 of 10441 images
# Trained 1824 of 10441 images
# Trained 1856 of 10441 images
# Trained 1888 of 10441 images
# Trained 1856 of 10441 images
# Trained 1920 of 10441 images
# Trained 1888 of 10441 images
# Trained 1952 of 10441 images
# Trained 1984 of 10441 images
# Trained 1920 of 10441 images
# Trained 2016 of 10441 images
# Trained 1952 of 10441 images
# Trained 1984 of 10441 images
# Trained 2048 of 10441 images
# Trained 2016 of 10441 images
# Trained 2080 of 10441 images
# Trained 2048 of 10441 images
# Trained 2112 of 10441 images
# Trained 2080 of 10441 images
# Trained 2144 of 10441 images
# Trained 2176 of 10441 images
# Trained 2112 of 10441 images
# Trained 2144 of 10441 images
# Trained 2208 of 10441 images
# Trained 2176 of 10441 images
# Trained 2240 of 10441 images
# Trained 2208 of 10441 images
# Trained 2272 of 10441 images
# Trained 2304 of 10441 images
# Trained 2336 of 10441 images
# Trained 2368 of 10441 images
# Trained 2400 of 10441 images
# Trained 2240 of 10441 images
# Trained 2272 of 10441 images
# Trained 2304 of 10441 images
# Trained 2336 of 10441 images
# Trained 2368 of 10441 images
# Trained 2432 of 10441 images
# Trained 2400 of 10441 images
# Trained 2464 of 10441 images
# Trained 2432 of 10441 images
# Trained 2496 of 10441 images
# Trained 2464 of 10441 images
# Trained 2528 of 10441 images
# Trained 2560 of 10441 images
# Trained 2496 of 10441 images
# Trained 2592 of 10441 images
# Trained 2528 of 10441 images
# Trained 2560 of 10441 images
# Trained 2624 of 10441 images
# Trained 2592 of 10441 images
# Trained 2656 of 10441 images
# Trained 2624 of 10441 images
# Trained 2688 of 10441 images
# Trained 2720 of 10441 images
# Trained 2656 of 10441 images
# Trained 2752 of 10441 images
# Trained 2688 of 10441 images
# Trained 2784 of 10441 images
# Trained 2720 of 10441 images
# Trained 2752 of 10441 images
# Trained 2784 of 10441 images
# Trained 2816 of 10441 images
# Trained 2848 of 10441 images
# Trained 2880 of 10441 images
# Trained 2816 of 10441 images
# Trained 2912 of 10441 images
# Trained 2848 of 10441 images
# Trained 2944 of 10441 images
# Trained 2880 of 10441 images
# Trained 2976 of 10441 images
# Trained 2912 of 10441 images
# Trained 2944 of 10441 images
# Trained 3008 of 10441 images
# Trained 2976 of 10441 images
# Trained 3040 of 10441 images
# Trained 3072 of 10441 images
# Trained 3008 of 10441 images
# Trained 3104 of 10441 images
# Trained 3040 of 10441 images
# Trained 3136 of 10441 images
# Trained 3072 of 10441 images
# Trained 3168 of 10441 images
# Trained 3104 of 10441 images
# Trained 3136 of 10441 images
# Trained 3168 of 10441 images
# Trained 3200 of 10441 images
# Trained 3232 of 10441 images
# Trained 3264 of 10441 images
# Trained 3200 of 10441 images
# Trained 3296 of 10441 images
# Trained 3232 of 10441 images
# Trained 3328 of 10441 images
# Trained 3264 of 10441 images
# Trained 3360 of 10441 images
# Trained 3296 of 10441 images
# Trained 3328 of 10441 images
# Trained 3392 of 10441 images
# Trained 3360 of 10441 images
# Trained 3424 of 10441 images
# Trained 3456 of 10441 images
# Trained 3392 of 10441 images
# Trained 3488 of 10441 images
# Trained 3424 of 10441 images
# Trained 3520 of 10441 images
# Trained 3456 of 10441 images
# Trained 3552 of 10441 images
# Trained 3488 of 10441 images
# Trained 3520 of 10441 images
# Trained 3584 of 10441 images
# Trained 3616 of 10441 images
# Trained 3552 of 10441 images
# Trained 3648 of 10441 images
# Trained 3584 of 10441 images
# Trained 3680 of 10441 images
# Trained 3616 of 10441 images
# Trained 3648 of 10441 images
# Trained 3712 of 10441 images
# Trained 3680 of 10441 images
# Trained 3744 of 10441 images
# Trained 3776 of 10441 images
# Trained 3712 of 10441 images
# Trained 3808 of 10441 images
# Trained 3744 of 10441 images
# Trained 3840 of 10441 images
# Trained 3776 of 10441 images
# Trained 3872 of 10441 images
# Trained 3808 of 10441 images
# Trained 3840 of 10441 images
# Trained 3904 of 10441 images
# Trained 3872 of 10441 images
# Trained 3904 of 10441 images
# Trained 3936 of 10441 images
# Trained 3968 of 10441 images
# Trained 4000 of 10441 images
# Trained 3936 of 10441 images
# Trained 4032 of 10441 images
# Trained 3968 of 10441 images
# Trained 4064 of 10441 images
# Trained 4000 of 10441 images
# Trained 4032 of 10441 images
# Trained 4096 of 10441 images
# Trained 4064 of 10441 images
# Trained 4128 of 10441 images
# Trained 4096 of 10441 images
# Trained 4160 of 10441 images
# Trained 4192 of 10441 images
# Trained 4128 of 10441 images
# Trained 4224 of 10441 images
# Trained 4160 of 10441 images
# Trained 4256 of 10441 images
# Trained 4192 of 10441 images
# Trained 4224 of 10441 images
# Trained 4288 of 10441 images
# Trained 4256 of 10441 images
# Trained 4288 of 10441 images
# Trained 4320 of 10441 images
# Trained 4352 of 10441 images
# Trained 4384 of 10441 images
# Trained 4320 of 10441 images
# Trained 4416 of 10441 images
# Trained 4352 of 10441 images
# Trained 4448 of 10441 images
# Trained 4384 of 10441 images
# Trained 4480 of 10441 images
# Trained 4512 of 10441 images
# Trained 4416 of 10441 images
# Trained 4544 of 10441 images
# Trained 4448 of 10441 images
# Trained 4576 of 10441 images
# Trained 4480 of 10441 images
# Trained 4608 of 10441 images
# Trained 4512 of 10441 images
# Trained 4640 of 10441 images
# Trained 4544 of 10441 images
# Trained 4672 of 10441 images
# Trained 4704 of 10441 images
# Trained 4576 of 10441 images
# Trained 4736 of 10441 images
# Trained 4768 of 10441 images
# Trained 4608 of 10441 images
# Trained 4800 of 10441 images
# Trained 4640 of 10441 images
# Trained 4832 of 10441 images
# Trained 4672 of 10441 images
# Trained 4864 of 10441 images
# Trained 4704 of 10441 images
# Trained 4736 of 10441 images
# Trained 4896 of 10441 images
# Trained 4928 of 10441 images
# Trained 4768 of 10441 images
# Trained 4960 of 10441 images
# Trained 4800 of 10441 images
# Trained 4992 of 10441 images
# Trained 4832 of 10441 images
# Trained 5024 of 10441 images
# Trained 4864 of 10441 images
# Trained 5056 of 10441 images
# Trained 4896 of 10441 images
# Trained 4928 of 10441 images
# Trained 5088 of 10441 images
# Trained 4960 of 10441 images
# Trained 5120 of 10441 images
# Trained 4992 of 10441 images
# Trained 5024 of 10441 images
# Trained 5152 of 10441 images
# Trained 5056 of 10441 images
# Trained 5088 of 10441 images
# Trained 5120 of 10441 images
# Trained 5184 of 10441 images
# Trained 5216 of 10441 images
# Trained 5152 of 10441 images
# Trained 5248 of 10441 images
# Trained 5184 of 10441 images
# Trained 5280 of 10441 images
# Trained 5216 of 10441 images
# Trained 5312 of 10441 images
# Trained 5344 of 10441 images
# Trained 5248 of 10441 images
# Trained 5376 of 10441 images
# Trained 5280 of 10441 images
# Trained 5312 of 10441 images
# Trained 5408 of 10441 images
# Trained 5344 of 10441 images
# Trained 5440 of 10441 images
# Trained 5376 of 10441 images
# Trained 5472 of 10441 images
# Trained 5408 of 10441 images
# Trained 5504 of 10441 images
# Trained 5536 of 10441 images
# Trained 5440 of 10441 images
# Trained 5472 of 10441 images
# Trained 5504 of 10441 images
# Trained 5568 of 10441 images
# Trained 5600 of 10441 images
# Trained 5536 of 10441 images
# Trained 5632 of 10441 images
# Trained 5568 of 10441 images
# Trained 5664 of 10441 images
# Trained 5600 of 10441 images
# Trained 5696 of 10441 images
# Trained 5632 of 10441 images
# Trained 5728 of 10441 images
# Trained 5664 of 10441 images
# Trained 5760 of 10441 images
# Trained 5696 of 10441 images
# Trained 5792 of 10441 images
# Trained 5728 of 10441 images
# Trained 5824 of 10441 images
# Trained 5856 of 10441 images
# Trained 5760 of 10441 images
# Trained 5888 of 10441 images
# Trained 5792 of 10441 images
# Trained 5824 of 10441 images
# Trained 5856 of 10441 images
# Trained 5920 of 10441 images
# Trained 5952 of 10441 images
# Trained 5888 of 10441 images
# Trained 5984 of 10441 images
# Trained 5920 of 10441 images
# Trained 6016 of 10441 images
# Trained 6048 of 10441 images
# Trained 5952 of 10441 images
# Trained 6080 of 10441 images
# Trained 5984 of 10441 images
# Trained 6016 of 10441 images
# Trained 6112 of 10441 images
# Trained 6048 of 10441 images
# Trained 6144 of 10441 images
# Trained 6080 of 10441 images
# Trained 6176 of 10441 images
# Trained 6208 of 10441 images
# Trained 6112 of 10441 images
# Trained 6240 of 10441 images
# Trained 6144 of 10441 images
# Trained 6272 of 10441 images
# Trained 6176 of 10441 images
# Trained 6208 of 10441 images
# Trained 6240 of 10441 images
# Trained 6304 of 10441 images
# Trained 6336 of 10441 images
# Trained 6272 of 10441 images
# Trained 6368 of 10441 images
# Trained 6304 of 10441 images
# Trained 6400 of 10441 images
# Trained 6432 of 10441 images
# Trained 6336 of 10441 images
# Trained 6464 of 10441 images
# Trained 6368 of 10441 images
# Trained 6496 of 10441 images
# Trained 6400 of 10441 images
# Trained 6528 of 10441 images
# Trained 6432 of 10441 images
# Trained 6464 of 10441 images
# Trained 6560 of 10441 images
# Trained 6496 of 10441 images
# Trained 6592 of 10441 images
# Trained 6624 of 10441 images
# Trained 6528 of 10441 images
# Trained 6656 of 10441 images
# Trained 6560 of 10441 images
# Trained 6688 of 10441 images
# Trained 6592 of 10441 images
# Trained 6720 of 10441 images
# Trained 6624 of 10441 images
# Trained 6656 of 10441 images
# Trained 6752 of 10441 images
# Trained 6784 of 10441 images
# Trained 6688 of 10441 images
# Trained 6816 of 10441 images
# Trained 6720 of 10441 images
# Trained 6848 of 10441 images
# Trained 6752 of 10441 images
# Trained 6784 of 10441 images
# Trained 6880 of 10441 images
# Trained 6912 of 10441 images
# Trained 6816 of 10441 images
# Trained 6848 of 10441 images
# Trained 6944 of 10441 images
# Trained 6976 of 10441 images
# Trained 6880 of 10441 images
# Trained 7008 of 10441 images
# Trained 6912 of 10441 images
# Trained 7040 of 10441 images
# Trained 6944 of 10441 images
# Trained 7072 of 10441 images
# Trained 6976 of 10441 images
# Trained 7104 of 10441 images
# Trained 7008 of 10441 images
# Trained 7040 of 10441 images
# Trained 7136 of 10441 images
# Trained 7168 of 10441 images
# Trained 7072 of 10441 images
# Trained 7200 of 10441 images
# Trained 7104 of 10441 images
# Trained 7232 of 10441 images
# Trained 7136 of 10441 images
# Trained 7168 of 10441 images
# Trained 7264 of 10441 images
# Trained 7296 of 10441 images
# Trained 7200 of 10441 images
# Trained 7232 of 10441 images
# Trained 7328 of 10441 images
# Trained 7360 of 10441 images
# Trained 7264 of 10441 images
# Trained 7392 of 10441 images
# Trained 7296 of 10441 images
# Trained 7424 of 10441 images
# Trained 7328 of 10441 images
# Trained 7456 of 10441 images
# Trained 7360 of 10441 images
# Trained 7488 of 10441 images
# Trained 7392 of 10441 images
# Trained 7520 of 10441 images
# Trained 7552 of 10441 images
# Trained 7424 of 10441 images
# Trained 7456 of 10441 images
# Trained 7584 of 10441 images
# Trained 7488 of 10441 images
# Trained 7616 of 10441 images
# Trained 7520 of 10441 images
# Trained 7648 of 10441 images
# Trained 7552 of 10441 images
# Trained 7680 of 10441 images
# Trained 7712 of 10441 images
# Trained 7744 of 10441 images
# Trained 7776 of 10441 images
# Trained 7808 of 10441 images
# Trained 7584 of 10441 images
# Trained 7616 of 10441 images
# Trained 7648 of 10441 images
# Trained 7680 of 10441 images
# Trained 7712 of 10441 images
# Trained 7840 of 10441 images
# Trained 7744 of 10441 images
# Trained 7872 of 10441 images
# Trained 7904 of 10441 images
# Trained 7776 of 10441 images
# Trained 7808 of 10441 images
# Trained 7936 of 10441 images
# Trained 7840 of 10441 images
# Trained 7968 of 10441 images
# Trained 7872 of 10441 images
# Trained 8000 of 10441 images
# Trained 7904 of 10441 images
# Trained 8032 of 10441 images
# Trained 7936 of 10441 images
# Trained 8064 of 10441 images
# Trained 8096 of 10441 images
# Trained 8128 of 10441 images
# Trained 8160 of 10441 images
# Trained 7968 of 10441 images
# Trained 8000 of 10441 images
# Trained 8032 of 10441 images
# Trained 8064 of 10441 images
# Trained 8192 of 10441 images
# Trained 8224 of 10441 images
# Trained 8096 of 10441 images
# Trained 8256 of 10441 images
# Trained 8128 of 10441 images
# Trained 8160 of 10441 images
# Trained 8288 of 10441 images
# Trained 8192 of 10441 images
# Trained 8320 of 10441 images
# Trained 8224 of 10441 images
# Trained 8352 of 10441 images
# Trained 8256 of 10441 images
# Trained 8384 of 10441 images
# Trained 8416 of 10441 images
# Trained 8288 of 10441 images
# Trained 8448 of 10441 images
# Trained 8320 of 10441 images
# Trained 8352 of 10441 images
# Trained 8480 of 10441 images
# Trained 8384 of 10441 images
# Trained 8512 of 10441 images
# Trained 8416 of 10441 images
# Trained 8544 of 10441 images
# Trained 8576 of 10441 images
# Trained 8448 of 10441 images
# Trained 8480 of 10441 images
# Trained 8608 of 10441 images
# Trained 8640 of 10441 images
# Trained 8512 of 10441 images
# Trained 8672 of 10441 images
# Trained 8544 of 10441 images
# Trained 8576 of 10441 images
# Trained 8704 of 10441 images
# Trained 8608 of 10441 images
# Trained 8736 of 10441 images
# Trained 8768 of 10441 images
# Trained 8640 of 10441 images
# Trained 8800 of 10441 images
# Trained 8672 of 10441 images
# Trained 8832 of 10441 images
# Trained 8704 of 10441 images
# Trained 8864 of 10441 images
# Trained 8736 of 10441 images
# Trained 8768 of 10441 images
# Trained 8896 of 10441 images
# Trained 8928 of 10441 images
# Trained 8800 of 10441 images
# Trained 8960 of 10441 images
# Trained 8832 of 10441 images
# Trained 8864 of 10441 images
# Trained 8992 of 10441 images
# Trained 9024 of 10441 images
# Trained 8896 of 10441 images
# Trained 8928 of 10441 images
# Trained 9056 of 10441 images
# Trained 8960 of 10441 images
# Trained 9088 of 10441 images
# Trained 9120 of 10441 images
# Trained 8992 of 10441 images
# Trained 9152 of 10441 images
# Trained 9024 of 10441 images
# Trained 9184 of 10441 images
# Trained 9056 of 10441 images
# Trained 9216 of 10441 images
# Trained 9088 of 10441 images
# Trained 9120 of 10441 images
# Trained 9248 of 10441 images
# Trained 9152 of 10441 images
# Trained 9280 of 10441 images
# Trained 9312 of 10441 images
# Trained 9184 of 10441 images
# Trained 9344 of 10441 images
# Trained 9216 of 10441 images
# Trained 9248 of 10441 images
# Trained 9376 of 10441 images
# Trained 9408 of 10441 images
# Trained 9280 of 10441 images
# Trained 9440 of 10441 images
# Trained 9312 of 10441 images
# Trained 9344 of 10441 images
# Trained 9472 of 10441 images
# Trained 9504 of 10441 images
# Trained 9376 of 10441 images
# Trained 9536 of 10441 images
# Trained 9408 of 10441 images
# Trained 9568 of 10441 images
# Trained 9440 of 10441 images
# Trained 9600 of 10441 images
# Trained 9472 of 10441 images
# Trained 9632 of 10441 images
# Trained 9504 of 10441 images
# Trained 9536 of 10441 images
# Trained 9664 of 10441 images
# Trained 9696 of 10441 images
# Trained 9568 of 10441 images
# Trained 9728 of 10441 images
# Trained 9600 of 10441 images
# Trained 9632 of 10441 images
# Trained 9760 of 10441 images
# Trained 9792 of 10441 images
# Trained 9664 of 10441 images
# Trained 9696 of 10441 images
# Trained 9824 of 10441 images
# Trained 9728 of 10441 images
# Trained 9856 of 10441 images
# Trained 9888 of 10441 images
# Trained 9760 of 10441 images
# Trained 9920 of 10441 images
# Trained 9792 of 10441 images
# Trained 9952 of 10441 images
# Trained 9824 of 10441 images
# Trained 9984 of 10441 images
# Trained 9856 of 10441 images
# Trained 10016 of 10441 images
# Trained 9888 of 10441 images
# Trained 9920 of 10441 images
# Trained 10048 of 10441 images
# Trained 10080 of 10441 images
# Trained 9952 of 10441 images
# Trained 10112 of 10441 images
# Trained 9984 of 10441 images
# Trained 10016 of 10441 images
# Trained 10144 of 10441 images
# Trained 10176 of 10441 images
# Trained 10048 of 10441 images
# Trained 10208 of 10441 images
# Trained 10080 of 10441 images
# Trained 10112 of 10441 images
# Trained 10240 of 10441 images
# Trained 10272 of 10441 images
# Trained 10144 of 10441 images
# Trained 10176 of 10441 images
# Trained 10304 of 10441 images
# Trained 10336 of 10441 images
# Trained 10368 of 10441 images
# Trained 10208 of 10441 images
# Trained 10400 of 10441 images
# Trained 10240 of 10441 images
# Trained 10272 of 10441 images
# Trained 10432 of 10441 images
# Trained 10441 of 10441 images
# Train Loss: 1.5198 Acc: 0.2770
# Trained 10304 of 10441 images
# Trained 10336 of 10441 images
# Trained 10368 of 10441 images
# Trained 10400 of 10441 images
# Trained 10432 of 10441 images
# Trained 10441 of 10441 images
# Train Loss: 1.5159 Acc: 0.2828
# Test Loss: 1.4574 Acc: 0.3035
# Epoch 2
# Trained 32 of 10441 images
# Trained 64 of 10441 images
# Trained 96 of 10441 images
# Trained 128 of 10441 images
# Trained 160 of 10441 images
# Test Loss: 1.4515 Acc: 0.3111
# Epoch 2
# Trained 32 of 10441 images
# Trained 64 of 10441 images
# Trained 192 of 10441 images
# Trained 96 of 10441 images
# Trained 224 of 10441 images
# Trained 128 of 10441 images
# Trained 160 of 10441 images
# Trained 256 of 10441 images
# Trained 192 of 10441 images
# Trained 288 of 10441 images
# Trained 224 of 10441 images
# Trained 320 of 10441 images
# Trained 256 of 10441 images
# Trained 352 of 10441 images
# Trained 384 of 10441 images
# Trained 288 of 10441 images
# Trained 416 of 10441 images
# Trained 320 of 10441 images
# Trained 352 of 10441 images
# Trained 448 of 10441 images
# Trained 480 of 10441 images
# Trained 512 of 10441 images
# Trained 384 of 10441 images
# Trained 416 of 10441 images
# Trained 448 of 10441 images
# Trained 544 of 10441 images
# Trained 480 of 10441 images
# Trained 576 of 10441 images
# Trained 608 of 10441 images
# Trained 512 of 10441 images
# Trained 544 of 10441 images
# Trained 640 of 10441 images
# Trained 576 of 10441 images
# Trained 672 of 10441 images
# Trained 608 of 10441 images
# Trained 704 of 10441 images
# Trained 640 of 10441 images
# Trained 736 of 10441 images
# Trained 672 of 10441 images
# Trained 768 of 10441 images
# Trained 704 of 10441 images
# Trained 800 of 10441 images
# Trained 736 of 10441 images
# Trained 832 of 10441 images
# Trained 864 of 10441 images
# Trained 768 of 10441 images
# Trained 800 of 10441 images
# Trained 896 of 10441 images
# Trained 832 of 10441 images
# Trained 864 of 10441 images
# Trained 896 of 10441 images
# Trained 928 of 10441 images
# Trained 960 of 10441 images
# Trained 992 of 10441 images
# Trained 928 of 10441 images
# Trained 1024 of 10441 images
# Trained 1056 of 10441 images
# Trained 960 of 10441 images
# Trained 992 of 10441 images
# Trained 1088 of 10441 images
# Trained 1024 of 10441 images
# Trained 1120 of 10441 images
# Trained 1056 of 10441 images
# Trained 1152 of 10441 images
# Trained 1088 of 10441 images
# Trained 1184 of 10441 images
# Trained 1120 of 10441 images
# Trained 1216 of 10441 images
# Trained 1152 of 10441 images
# Trained 1248 of 10441 images
# Trained 1184 of 10441 images
# Trained 1216 of 10441 images
# Trained 1248 of 10441 images
# Trained 1280 of 10441 images
# Trained 1280 of 10441 images
# Trained 1312 of 10441 images
# Trained 1344 of 10441 images
# Trained 1376 of 10441 images
# Trained 1312 of 10441 images
# Trained 1408 of 10441 images
# Trained 1344 of 10441 images
# Trained 1440 of 10441 images
# Trained 1376 of 10441 images
# Trained 1472 of 10441 images
# Trained 1504 of 10441 images
# Trained 1408 of 10441 images
# Trained 1440 of 10441 images
# Trained 1536 of 10441 images
# Trained 1472 of 10441 images
# Trained 1568 of 10441 images
# Trained 1504 of 10441 images
# Trained 1600 of 10441 images
# Trained 1536 of 10441 images
# Trained 1632 of 10441 images
# Trained 1568 of 10441 images
# Trained 1664 of 10441 images
# Trained 1600 of 10441 images
# Trained 1632 of 10441 images
# Trained 1696 of 10441 images
# Trained 1728 of 10441 images
# Trained 1664 of 10441 images
# Trained 1760 of 10441 images
# Trained 1792 of 10441 images
# Trained 1696 of 10441 images
# Trained 1728 of 10441 images
# Trained 1760 of 10441 images
# Trained 1824 of 10441 images
# Trained 1792 of 10441 images
# Trained 1856 of 10441 images
# Trained 1888 of 10441 images
# Trained 1824 of 10441 images
# Trained 1920 of 10441 images
# Trained 1856 of 10441 images
# Trained 1952 of 10441 images
# Trained 1888 of 10441 images
# Trained 1984 of 10441 images
# Trained 1920 of 10441 images
# Trained 2016 of 10441 images
# Trained 1952 of 10441 images
# Trained 2048 of 10441 images
# Trained 1984 of 10441 images
# Trained 2016 of 10441 images
# Trained 2080 of 10441 images
# Trained 2112 of 10441 images
# Trained 2144 of 10441 images
# Trained 2176 of 10441 images
# Trained 2048 of 10441 images
# Trained 2080 of 10441 images
# Trained 2112 of 10441 images
# Trained 2208 of 10441 images
# Trained 2144 of 10441 images
# Trained 2240 of 10441 images
# Trained 2176 of 10441 images
# Trained 2208 of 10441 images
# Trained 2272 of 10441 images
# Trained 2240 of 10441 images
# Trained 2304 of 10441 images
# Trained 2336 of 10441 images
# Trained 2272 of 10441 images
# Trained 2368 of 10441 images
# Trained 2304 of 10441 images
# Trained 2400 of 10441 images
# Trained 2336 of 10441 images
# Trained 2432 of 10441 images
# Trained 2368 of 10441 images
# Trained 2400 of 10441 images
# Trained 2464 of 10441 images
# Trained 2496 of 10441 images
# Trained 2528 of 10441 images
# Trained 2560 of 10441 images
# Trained 2432 of 10441 images
# Trained 2464 of 10441 images
# Trained 2496 of 10441 images
# Trained 2592 of 10441 images
# Trained 2528 of 10441 images
# Trained 2624 of 10441 images
# Trained 2560 of 10441 images
# Trained 2592 of 10441 images
# Trained 2656 of 10441 images
# Trained 2624 of 10441 images
# Trained 2688 of 10441 images
# Trained 2656 of 10441 images
# Trained 2720 of 10441 images
# Trained 2688 of 10441 images
# Trained 2752 of 10441 images
# Trained 2784 of 10441 images
# Trained 2720 of 10441 images
# Trained 2816 of 10441 images
# Trained 2752 of 10441 images
# Trained 2784 of 10441 images
# Trained 2848 of 10441 images
# Trained 2816 of 10441 images
# Trained 2880 of 10441 images
# Trained 2848 of 10441 images
# Trained 2912 of 10441 images
# Trained 2880 of 10441 images
# Trained 2912 of 10441 images
# Trained 2944 of 10441 images
# Trained 2944 of 10441 images
# Trained 2976 of 10441 images
# Trained 3008 of 10441 images
# Trained 2976 of 10441 images
# Trained 3008 of 10441 images
# Trained 3040 of 10441 images
# Trained 3040 of 10441 images
# Trained 3072 of 10441 images
# Trained 3072 of 10441 images
# Trained 3104 of 10441 images
# Trained 3104 of 10441 images
# Trained 3136 of 10441 images
# Trained 3136 of 10441 images
# Trained 3168 of 10441 images
# Trained 3200 of 10441 images
# Trained 3168 of 10441 images
# Trained 3232 of 10441 images
# Trained 3200 of 10441 images
# Trained 3264 of 10441 images
# Trained 3232 of 10441 images
# Trained 3264 of 10441 images
# Trained 3296 of 10441 images
# Trained 3296 of 10441 images
# Trained 3328 of 10441 images
# Trained 3360 of 10441 images
# Trained 3328 of 10441 images
# Trained 3360 of 10441 images
# Trained 3392 of 10441 images
# Trained 3392 of 10441 images
# Trained 3424 of 10441 images
# Trained 3456 of 10441 images
# Trained 3424 of 10441 images
# Trained 3488 of 10441 images
# Trained 3456 of 10441 images
# Trained 3520 of 10441 images
# Trained 3488 of 10441 images
# Trained 3552 of 10441 images
# Trained 3520 of 10441 images
# Trained 3584 of 10441 images
# Trained 3552 of 10441 images
# Trained 3616 of 10441 images
# Trained 3648 of 10441 images
# Trained 3584 of 10441 images
# Trained 3616 of 10441 images
# Trained 3648 of 10441 images
# Trained 3680 of 10441 images
# Trained 3680 of 10441 images
# Trained 3712 of 10441 images
# Trained 3744 of 10441 images
# Trained 3712 of 10441 images
# Trained 3776 of 10441 images
# Trained 3744 of 10441 images
# Trained 3808 of 10441 images
# Trained 3840 of 10441 images
# Trained 3776 of 10441 images
# Trained 3808 of 10441 images
# Trained 3872 of 10441 images
# Trained 3840 of 10441 images
# Trained 3904 of 10441 images
# Trained 3872 of 10441 images
# Trained 3936 of 10441 images
# Trained 3904 of 10441 images
# Trained 3968 of 10441 images
# Trained 3936 of 10441 images
# Trained 4000 of 10441 images
# Trained 3968 of 10441 images
# Trained 4032 of 10441 images
# Trained 4000 of 10441 images
# Trained 4064 of 10441 images
# Trained 4032 of 10441 images
# Trained 4096 of 10441 images
# Trained 4128 of 10441 images
# Trained 4160 of 10441 images
# Trained 4064 of 10441 images
# Trained 4096 of 10441 images
# Trained 4128 of 10441 images
# Trained 4160 of 10441 images
# Trained 4192 of 10441 images
# Trained 4192 of 10441 images
# Trained 4224 of 10441 images
# Trained 4224 of 10441 images
# Trained 4256 of 10441 images
# Trained 4288 of 10441 images
# Trained 4256 of 10441 images
# Trained 4320 of 10441 images
# Trained 4288 of 10441 images
# Trained 4352 of 10441 images
# Trained 4320 of 10441 images
# Trained 4352 of 10441 images
# Trained 4384 of 10441 images
# Trained 4384 of 10441 images
# Trained 4416 of 10441 images
# Trained 4416 of 10441 images
# Trained 4448 of 10441 images
# Trained 4480 of 10441 images
# Trained 4512 of 10441 images
# Trained 4544 of 10441 images
# Trained 4448 of 10441 images
# Trained 4480 of 10441 images
# Trained 4512 of 10441 images
# Trained 4576 of 10441 images
# Trained 4544 of 10441 images
# Trained 4576 of 10441 images
# Trained 4608 of 10441 images
# Trained 4608 of 10441 images
# Trained 4640 of 10441 images
# Trained 4640 of 10441 images
# Trained 4672 of 10441 images
# Trained 4672 of 10441 images
# Trained 4704 of 10441 images
# Trained 4736 of 10441 images
# Trained 4704 of 10441 images
# Trained 4768 of 10441 images
# Trained 4736 of 10441 images
# Trained 4800 of 10441 images
# Trained 4768 of 10441 images
# Trained 4800 of 10441 images
# Trained 4832 of 10441 images
# Trained 4864 of 10441 images
# Trained 4896 of 10441 images
# Trained 4928 of 10441 images
# Trained 4832 of 10441 images
# Trained 4864 of 10441 images
# Trained 4896 of 10441 images
# Trained 4960 of 10441 images
# Trained 4928 of 10441 images
# Trained 4992 of 10441 images
# Trained 4960 of 10441 images
# Trained 5024 of 10441 images
# Trained 4992 of 10441 images
# Trained 5056 of 10441 images
# Trained 5024 of 10441 images
# Trained 5088 of 10441 images
# Trained 5056 of 10441 images
# Trained 5088 of 10441 images
# Trained 5120 of 10441 images
# Trained 5120 of 10441 images
# Trained 5152 of 10441 images
# Trained 5152 of 10441 images
# Trained 5184 of 10441 images
# Trained 5216 of 10441 images
# Trained 5184 of 10441 images
# Trained 5248 of 10441 images
# Trained 5216 of 10441 images
# Trained 5280 of 10441 images
# Trained 5248 of 10441 images
# Trained 5280 of 10441 images
# Trained 5312 of 10441 images
# Trained 5344 of 10441 images
# Trained 5312 of 10441 images
# Trained 5344 of 10441 images
# Trained 5376 of 10441 images
# Trained 5408 of 10441 images
# Trained 5376 of 10441 images
# Trained 5440 of 10441 images
# Trained 5408 of 10441 images
# Trained 5472 of 10441 images
# Trained 5440 of 10441 images
# Trained 5504 of 10441 images
# Trained 5472 of 10441 images
# Trained 5504 of 10441 images
# Trained 5536 of 10441 images
# Trained 5568 of 10441 images
# Trained 5536 of 10441 images
# Trained 5600 of 10441 images
# Trained 5568 of 10441 images
# Trained 5632 of 10441 images
# Trained 5600 of 10441 images
# Trained 5664 of 10441 images
# Trained 5632 of 10441 images
# Trained 5664 of 10441 images
# Trained 5696 of 10441 images
# Trained 5728 of 10441 images
# Trained 5696 of 10441 images
# Trained 5728 of 10441 images
# Trained 5760 of 10441 images
# Trained 5792 of 10441 images
# Trained 5760 of 10441 images
# Trained 5824 of 10441 images
# Trained 5792 of 10441 images
# Trained 5856 of 10441 images
# Trained 5824 of 10441 images
# Trained 5888 of 10441 images
# Trained 5856 of 10441 images
# Trained 5920 of 10441 images
# Trained 5888 of 10441 images
# Trained 5920 of 10441 images
# Trained 5952 of 10441 images
# Trained 5952 of 10441 images
# Trained 5984 of 10441 images
# Trained 5984 of 10441 images
# Trained 6016 of 10441 images
# Trained 6048 of 10441 images
# Trained 6016 of 10441 images
# Trained 6080 of 10441 images
# Trained 6048 of 10441 images
# Trained 6112 of 10441 images
# Trained 6080 of 10441 images
# Trained 6112 of 10441 images
# Trained 6144 of 10441 images
# Trained 6176 of 10441 images
# Trained 6208 of 10441 images
# Trained 6144 of 10441 images
# Trained 6176 of 10441 images
# Trained 6240 of 10441 images
# Trained 6208 of 10441 images
# Trained 6240 of 10441 images
# Trained 6272 of 10441 images
# Trained 6272 of 10441 images
# Trained 6304 of 10441 images
# Trained 6304 of 10441 images
# Trained 6336 of 10441 images
# Trained 6336 of 10441 images
# Trained 6368 of 10441 images
# Trained 6368 of 10441 images
# Trained 6400 of 10441 images
# Trained 6432 of 10441 images
# Trained 6400 of 10441 images
# Trained 6464 of 10441 images
# Trained 6432 of 10441 images
# Trained 6464 of 10441 images
# Trained 6496 of 10441 images
# Trained 6496 of 10441 images
# Trained 6528 of 10441 images
# Trained 6560 of 10441 images
# Trained 6528 of 10441 images
# Trained 6560 of 10441 images
# Trained 6592 of 10441 images
# Trained 6592 of 10441 images
# Trained 6624 of 10441 images
# Trained 6624 of 10441 images
# Trained 6656 of 10441 images
# Trained 6656 of 10441 images
# Trained 6688 of 10441 images
# Trained 6688 of 10441 images
# Trained 6720 of 10441 images
# Trained 6720 of 10441 images
# Trained 6752 of 10441 images
# Trained 6752 of 10441 images
# Trained 6784 of 10441 images
# Trained 6784 of 10441 images
# Trained 6816 of 10441 images
# Trained 6816 of 10441 images
# Trained 6848 of 10441 images
# Trained 6848 of 10441 images
# Trained 6880 of 10441 images
# Trained 6880 of 10441 images
# Trained 6912 of 10441 images
# ...
# Trained 1760 of 10441 images
# Trained 2304 of 10441 images
# Trained 1792 of 10441 images
# Trained 2336 of 10441 images
# Trained 2368 of 10441 images
# Trained 1824 of 10441 images
# Trained 2400 of 10441 images
# Trained 1856 of 10441 images
# Trained 2432 of 10441 images
# Trained 1888 of 10441 images
# Trained 2464 of 10441 images
# Trained 1920 of 10441 images
# Trained 1952 of 10441 images
# Trained 2496 of 10441 images
# Trained 1984 of 10441 images
# Trained 2528 of 10441 images
# Trained 2016 of 10441 images
# Trained 2560 of 10441 images
# Trained 2592 of 10441 images
# Trained 2048 of 10441 images
# Trained 2624 of 10441 images
# Trained 2080 of 10441 images
# Trained 2656 of 10441 images
# Trained 2112 of 10441 images
# Trained 2688 of 10441 images
# Trained 2144 of 10441 images
# Trained 2176 of 10441 images
# Trained 2720 of 10441 images
# Trained 2208 of 10441 images
# Trained 2752 of 10441 images
# Trained 2784 of 10441 images
# Trained 2240 of 10441 images
# Trained 2816 of 10441 images
# Trained 2272 of 10441 images
# Trained 2848 of 10441 images
# Trained 2304 of 10441 images
# Trained 2880 of 10441 images
# Trained 2336 of 10441 images
# Trained 2912 of 10441 images
# Trained 2368 of 10441 images
# Trained 2400 of 10441 images
# Trained 2944 of 10441 images
# Trained 2432 of 10441 images
# Trained 2976 of 10441 images
# Trained 3008 of 10441 images
# Trained 3040 of 10441 images
# Trained 3072 of 10441 images
# Trained 3104 of 10441 images
# Trained 3136 of 10441 images
# Trained 3168 of 10441 images
# Trained 3200 of 10441 images
# Trained 2464 of 10441 images
# Trained 2496 of 10441 images
# Trained 2528 of 10441 images
# Trained 2560 of 10441 images
# Trained 2592 of 10441 images
# Trained 2624 of 10441 images
# Trained 2656 of 10441 images
# Trained 3232 of 10441 images
# Trained 2688 of 10441 images
# Trained 3264 of 10441 images
# Trained 2720 of 10441 images
# Trained 3296 of 10441 images
# Trained 2752 of 10441 images
# Trained 2784 of 10441 images
# Trained 3328 of 10441 images
# Trained 2816 of 10441 images
# Trained 3360 of 10441 images
# Trained 3392 of 10441 images
# Trained 2848 of 10441 images
# Trained 3424 of 10441 images
# Trained 2880 of 10441 images
# Trained 3456 of 10441 images
# Trained 2912 of 10441 images
# Trained 3488 of 10441 images
# Trained 2944 of 10441 images
# Trained 3520 of 10441 images
# Trained 2976 of 10441 images
# Trained 3008 of 10441 images
# Trained 3552 of 10441 images
# Trained 3040 of 10441 images
# Trained 3584 of 10441 images
# Trained 3616 of 10441 images
# Trained 3072 of 10441 images
# Trained 3648 of 10441 images
# Trained 3104 of 10441 images
# Trained 3680 of 10441 images
# Trained 3136 of 10441 images
# Trained 3168 of 10441 images
# Trained 3712 of 10441 images
# Trained 3200 of 10441 images
# Trained 3744 of 10441 images
# Trained 3232 of 10441 images
# Trained 3776 of 10441 images
# Trained 3264 of 10441 images
# Trained 3808 of 10441 images
# Trained 3840 of 10441 images
# Trained 3296 of 10441 images
# Trained 3872 of 10441 images
# Trained 3328 of 10441 images
# Trained 3360 of 10441 images
# Trained 3904 of 10441 images
# Trained 3392 of 10441 images
# Trained 3936 of 10441 images
# Trained 3424 of 10441 images
# Trained 3968 of 10441 images
# Trained 3456 of 10441 images
# Trained 4000 of 10441 images
# Trained 3488 of 10441 images
# Trained 4032 of 10441 images
# Trained 4064 of 10441 images
# Trained 3520 of 10441 images
# Trained 3552 of 10441 images
# Trained 4096 of 10441 images
# Trained 3584 of 10441 images
# Trained 4128 of 10441 images
# Trained 3616 of 10441 images
# Trained 4160 of 10441 images
# Trained 3648 of 10441 images
# Trained 4192 of 10441 images
# Trained 3680 of 10441 images
# Trained 4224 of 10441 images
# Trained 4256 of 10441 images
# Trained 3712 of 10441 images
# Trained 4288 of 10441 images
# Trained 3744 of 10441 images
# Trained 4320 of 10441 images
# Trained 3776 of 10441 images
# Trained 4352 of 10441 images
# Trained 3808 of 10441 images
# Trained 3840 of 10441 images
# Trained 4384 of 10441 images
# Trained 3872 of 10441 images
# Trained 4416 of 10441 images
# Trained 3904 of 10441 images
# Trained 4448 of 10441 images
# Trained 4480 of 10441 images
# Trained 3936 of 10441 images
# Trained 4512 of 10441 images
# Trained 3968 of 10441 images
# Trained 4544 of 10441 images
# Trained 4000 of 10441 images
# Trained 4032 of 10441 images
# Trained 4576 of 10441 images
# Trained 4064 of 10441 images
# Trained 4608 of 10441 images
# Trained 4096 of 10441 images
# Trained 4640 of 10441 images
# Trained 4128 of 10441 images
# Trained 4672 of 10441 images
# Trained 4704 of 10441 images
# Trained 4160 of 10441 images
# Trained 4736 of 10441 images
# Trained 4192 of 10441 images
# Trained 4224 of 10441 images
# Trained 4768 of 10441 images
# Trained 4256 of 10441 images
# Trained 4800 of 10441 images
# Trained 4288 of 10441 images
# Trained 4832 of 10441 images
# Trained 4320 of 10441 images
# Trained 4864 of 10441 images
# Trained 4352 of 10441 images
# Trained 4384 of 10441 images
# Trained 4896 of 10441 images
# Trained 4928 of 10441 images
# Trained 4416 of 10441 images
# Trained 4960 of 10441 images
# Trained 4448 of 10441 images
# Trained 4992 of 10441 images
# Trained 4480 of 10441 images
# Trained 5024 of 10441 images
# Trained 4512 of 10441 images
# Trained 5056 of 10441 images
# Trained 4544 of 10441 images
# Trained 5088 of 10441 images
# Trained 5120 of 10441 images
# Trained 4576 of 10441 images
# Trained 4608 of 10441 images
# Trained 5152 of 10441 images
# Trained 4640 of 10441 images
# Trained 5184 of 10441 images
# Trained 4672 of 10441 images
# Trained 5216 of 10441 images
# Trained 4704 of 10441 images
# Trained 5248 of 10441 images
# Trained 4736 of 10441 images
# Trained 5280 of 10441 images
# Trained 5312 of 10441 images
# Trained 4768 of 10441 images
# Trained 5344 of 10441 images
# Trained 4800 of 10441 images
# Trained 4832 of 10441 images
# Trained 5376 of 10441 images
# Trained 4864 of 10441 images
# Trained 5408 of 10441 images
# Trained 4896 of 10441 images
# Trained 5440 of 10441 images
# Trained 4928 of 10441 images
# Trained 5472 of 10441 images
# Trained 4960 of 10441 images
# Trained 5504 of 10441 images
# Trained 5536 of 10441 images
# Trained 4992 of 10441 images
# Trained 5568 of 10441 images
# Trained 5024 of 10441 images
# Trained 5056 of 10441 images
# Trained 5600 of 10441 images
# Trained 5088 of 10441 images
# Trained 5632 of 10441 images
# Trained 5120 of 10441 images
# Trained 5664 of 10441 images
# Trained 5152 of 10441 images
# Trained 5696 of 10441 images
# Trained 5728 of 10441 images
# Trained 5184 of 10441 images
# Trained 5760 of 10441 images
# Trained 5216 of 10441 images
# Trained 5792 of 10441 images
# Trained 5248 of 10441 images
# Trained 5280 of 10441 images
# Trained 5824 of 10441 images
# Trained 5312 of 10441 images
# Trained 5856 of 10441 images
# Trained 5344 of 10441 images
# Trained 5888 of 10441 images
# Trained 5376 of 10441 images
# Trained 5920 of 10441 images
# Trained 5952 of 10441 images
# Trained 5408 of 10441 images
# Trained 5984 of 10441 images
# Trained 5440 of 10441 images
# Trained 5472 of 10441 images
# Trained 6016 of 10441 images
# Trained 5504 of 10441 images
# Trained 6048 of 10441 images
# Trained 5536 of 10441 images
# Trained 6080 of 10441 images
# Trained 5568 of 10441 images
# Trained 6112 of 10441 images
# Trained 5600 of 10441 images
# Trained 6144 of 10441 images
# Trained 6176 of 10441 images
# Trained 5632 of 10441 images
# Trained 5664 of 10441 images
# Trained 6208 of 10441 images
# Trained 5696 of 10441 images
# Trained 6240 of 10441 images
# Trained 5728 of 10441 images
# Trained 6272 of 10441 images
# Trained 5760 of 10441 images
# Trained 6304 of 10441 images
# Trained 5792 of 10441 images
# Trained 6336 of 10441 images
# Trained 5824 of 10441 images
# Trained 6368 of 10441 images
# Trained 5856 of 10441 images
# Trained 5888 of 10441 images
# Trained 6400 of 10441 images
# Trained 6432 of 10441 images
# Trained 5920 of 10441 images
# Trained 6464 of 10441 images
# Trained 5952 of 10441 images
# Trained 6496 of 10441 images
# Trained 5984 of 10441 images
# Trained 6528 of 10441 images
# Trained 6016 of 10441 images
# Trained 6560 of 10441 images
# Trained 6048 of 10441 images
# Trained 6592 of 10441 images
# Trained 6080 of 10441 images
# Trained 6112 of 10441 images
# Trained 6624 of 10441 images
# Trained 6656 of 10441 images
# Trained 6144 of 10441 images
# Trained 6688 of 10441 images
# Trained 6176 of 10441 images
# Trained 6720 of 10441 images
# Trained 6208 of 10441 images
# Trained 6752 of 10441 images
# Trained 6240 of 10441 images
# Trained 6784 of 10441 images
# Trained 6272 of 10441 images
# Trained 6816 of 10441 images
# Trained 6304 of 10441 images
# Trained 6848 of 10441 images
# Trained 6880 of 10441 images
# Trained 6336 of 10441 images
# Trained 6368 of 10441 images
# Trained 6912 of 10441 images
# Trained 6400 of 10441 images
# Trained 6944 of 10441 images
# Trained 6432 of 10441 images
# Trained 6976 of 10441 images
# Trained 6464 of 10441 images
# Trained 7008 of 10441 images
# Trained 6496 of 10441 images
# Trained 7040 of 10441 images
# Trained 6528 of 10441 images
# Trained 7072 of 10441 images
# Trained 7104 of 10441 images
# Trained 6560 of 10441 images
# Trained 6592 of 10441 images
# Trained 7136 of 10441 images
# Trained 6624 of 10441 images
# Trained 7168 of 10441 images
# Trained 6656 of 10441 images
# Trained 7200 of 10441 images
# Trained 6688 of 10441 images
# Trained 7232 of 10441 images
# Trained 6720 of 10441 images
# Trained 7264 of 10441 images
# Trained 6752 of 10441 images
# Trained 6784 of 10441 images
# Trained 7296 of 10441 images
# Trained 7328 of 10441 images
# Trained 6816 of 10441 images
# Trained 7360 of 10441 images
# Trained 6848 of 10441 images
# Trained 7392 of 10441 images
# Trained 6880 of 10441 images
# Trained 7424 of 10441 images
# Trained 6912 of 10441 images
# Trained 7456 of 10441 images
# Trained 6944 of 10441 images
# Trained 6976 of 10441 images
# Trained 7488 of 10441 images
# Trained 7008 of 10441 images
# Trained 7520 of 10441 images
# Trained 7552 of 10441 images
# Trained 7040 of 10441 images
# Trained 7584 of 10441 images
# Trained 7072 of 10441 images
# Trained 7616 of 10441 images
# Trained 7104 of 10441 images
# Trained 7648 of 10441 images
# Trained 7136 of 10441 images
# Trained 7680 of 10441 images
# Trained 7168 of 10441 images
# Trained 7200 of 10441 images
# Trained 7712 of 10441 images
# Trained 7744 of 10441 images
# Trained 7232 of 10441 images
# Trained 7776 of 10441 images
# Trained 7264 of 10441 images
# Trained 7808 of 10441 images
# Trained 7296 of 10441 images
# Trained 7840 of 10441 images
# Trained 7328 of 10441 images
# Trained 7872 of 10441 images
# Trained 7360 of 10441 images
# Trained 7392 of 10441 images
# Trained 7904 of 10441 images
# Trained 7424 of 10441 images
# Trained 7936 of 10441 images
# Trained 7968 of 10441 images
# Trained 7456 of 10441 images
# Trained 8000 of 10441 images
# Trained 7488 of 10441 images
# Trained 8032 of 10441 images
# Trained 7520 of 10441 images
# Trained 8064 of 10441 images
# Trained 7552 of 10441 images
# Trained 7584 of 10441 images
# Trained 8096 of 10441 images
# Trained 7616 of 10441 images
# Trained 8128 of 10441 images
# Trained 8160 of 10441 images
# Trained 7648 of 10441 images
# Trained 8192 of 10441 images
# Trained 7680 of 10441 images
# Trained 8224 of 10441 images
# Trained 7712 of 10441 images
# Trained 8256 of 10441 images
# Trained 7744 of 10441 images
# Trained 7776 of 10441 images
# Trained 8288 of 10441 images
# Trained 7808 of 10441 images
# Trained 8320 of 10441 images
# Trained 7840 of 10441 images
# Trained 8352 of 10441 images
# Trained 7872 of 10441 images
# Trained 8384 of 10441 images
# Trained 8416 of 10441 images
# Trained 7904 of 10441 images
# Trained 8448 of 10441 images
# Trained 7936 of 10441 images
# Trained 8480 of 10441 images
# Trained 7968 of 10441 images
# Trained 8000 of 10441 images
# Trained 8512 of 10441 images
# Trained 8032 of 10441 images
# Trained 8544 of 10441 images
# Trained 8064 of 10441 images
# Trained 8576 of 10441 images
# Trained 8096 of 10441 images
# Trained 8608 of 10441 images
# Trained 8640 of 10441 images
# Trained 8128 of 10441 images
# Trained 8672 of 10441 images
# Trained 8160 of 10441 images
# Trained 8192 of 10441 images
# Trained 8704 of 10441 images
# Trained 8224 of 10441 images
# Trained 8736 of 10441 images
# Trained 8256 of 10441 images
# Trained 8768 of 10441 images
# Trained 8288 of 10441 images
# Trained 8800 of 10441 images
# Trained 8320 of 10441 images
# Trained 8832 of 10441 images
# Trained 8864 of 10441 images
# Trained 8352 of 10441 images
# Trained 8896 of 10441 images
# Trained 8384 of 10441 images
# Trained 8416 of 10441 images
# Trained 8928 of 10441 images
# Trained 8448 of 10441 images
# Trained 8960 of 10441 images
# Trained 8480 of 10441 images
# Trained 8992 of 10441 images
# Trained 8512 of 10441 images
# Trained 9024 of 10441 images
# Trained 8544 of 10441 images
# Trained 8576 of 10441 images
# Trained 9056 of 10441 images
# Trained 9088 of 10441 images
# Trained 8608 of 10441 images
# Trained 9120 of 10441 images
# Trained 8640 of 10441 images
# Trained 9152 of 10441 images
# Trained 8672 of 10441 images
# Trained 9184 of 10441 images
# Trained 8704 of 10441 images
# Trained 9216 of 10441 images
# Trained 8736 of 10441 images
# Trained 8768 of 10441 images
# Trained 9248 of 10441 images
# Trained 9280 of 10441 images
# Trained 8800 of 10441 images
# Trained 9312 of 10441 images
# Trained 8832 of 10441 images
# Trained 9344 of 10441 images
# Trained 8864 of 10441 images
# Trained 9376 of 10441 images
# Trained 8896 of 10441 images
# Trained 9408 of 10441 images
# Trained 8928 of 10441 images
# Trained 8960 of 10441 images
# Trained 9440 of 10441 images
# Trained 8992 of 10441 images
# Trained 9472 of 10441 images
# Trained 9504 of 10441 images
# Trained 9024 of 10441 images
# Trained 9536 of 10441 images
# Trained 9056 of 10441 images
# Trained 9568 of 10441 images
# Trained 9600 of 10441 images
# Trained 9632 of 10441 images
# Trained 9664 of 10441 images
# Trained 9696 of 10441 images
# Trained 9728 of 10441 images
# Trained 9760 of 10441 images
# Trained 9088 of 10441 images
# Trained 9120 of 10441 images
# Trained 9152 of 10441 images
# Trained 9184 of 10441 images
# Trained 9216 of 10441 images
# Trained 9248 of 10441 images
# Trained 9280 of 10441 images
# Trained 9792 of 10441 images
# Trained 9312 of 10441 images
# Trained 9824 of 10441 images
# Trained 9344 of 10441 images
# Trained 9376 of 10441 images
# Trained 9856 of 10441 images
# Trained 9408 of 10441 images
# Trained 9888 of 10441 images
# Trained 9440 of 10441 images
# Trained 9920 of 10441 images
# Trained 9952 of 10441 images
# Trained 9472 of 10441 images
# Trained 9984 of 10441 images
# Trained 9504 of 10441 images
# Trained 10016 of 10441 images
# Trained 9536 of 10441 images
# Trained 10048 of 10441 images
# Trained 9568 of 10441 images
# Trained 9600 of 10441 images
# Trained 10080 of 10441 images
# Trained 10112 of 10441 images
# Trained 9632 of 10441 images
# Trained 10144 of 10441 images
# Trained 9664 of 10441 images
# Trained 10176 of 10441 images
# Trained 9696 of 10441 images
# Trained 10208 of 10441 images
# Trained 9728 of 10441 images
# Trained 10240 of 10441 images
# Trained 9760 of 10441 images
# Trained 9792 of 10441 images
# Trained 10272 of 10441 images
# Trained 9824 of 10441 images
# Trained 10304 of 10441 images
# Trained 10336 of 10441 images
# Trained 9856 of 10441 images
# Trained 10368 of 10441 images
# Trained 9888 of 10441 images
# Trained 10400 of 10441 images
# Trained 9920 of 10441 images
# Trained 9952 of 10441 images
# Trained 10432 of 10441 images
# Trained 10441 of 10441 images
# Train Loss: 1.3808 Acc: 0.3770
# Trained 9984 of 10441 images
# Trained 10016 of 10441 images
# Trained 10048 of 10441 images
# Trained 10080 of 10441 images
# Trained 10112 of 10441 images
# Trained 10144 of 10441 images
# Trained 10176 of 10441 images
# Trained 10208 of 10441 images
# Trained 10240 of 10441 images
# Trained 10272 of 10441 images
# Trained 10304 of 10441 images
# Trained 10336 of 10441 images
# Trained 10368 of 10441 images
# Trained 10400 of 10441 images
# Trained 10432 of 10441 images
# Trained 10441 of 10441 images
# Train Loss: 1.3903 Acc: 0.3642
# Test Loss: 1.3427 Acc: 0.3965
# Training took 4763.8360 seconds
# Saving model to /opt/ml/model/model.pth
# 2023-04-16 00:48:53,598 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Test Loss: 1.3625 Acc: 0.3763
# Training took 4777.7987 seconds
# Saving model to /opt/ml/model/model.pth
# 2023-04-16 00:49:06,619 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2023-04-16 00:49:32 Uploading - Uploading generated training model
# 2023-04-16 00:49:32 Completed - Training job completed
# Training seconds: 9862
# Billable seconds: 9862

# %% [markdown]
# ## Standout Suggestions
# You do not need to perform the tasks below to finish your project. However, you can attempt these tasks to turn your project into a more advanced portfolio piece.

# %% [markdown]
# ### Hyperparameter Tuning
# **TODO:** Here you can perform hyperparameter tuning to increase the performance of your model. You are encouraged to
# - tune as many hyperparameters as you can to get the best performance from your model
# - explain why you chose to tune those particular hyperparameters and the ranges.

# %%
#TODO: Create your hyperparameter search space

# %%
#TODO: Create your training estimator

# %%
# TODO: Fit your estimator

# %%
# TODO: Find the best hyperparameters

# %% [markdown]
# ### Model Profiling and Debugging
# **TODO:** Use model debugging and profiling to better monitor and debug your model training job.

# %%
# TODO: Set up debugging and profiling rules and hooks

# %%
# TODO: Create and fit an estimator

# %%
# TODO: Plot a debugging output.

# %% [markdown]
# **TODO**: Is there some anomalous behaviour in your debugging output? If so, what is the error and how will you fix it?
# **TODO**: If not, suppose there was an error. What would that error look like and how would you have fixed it?

# %%
# TODO: Display the profiler output

# %% [markdown]
# ### Model Deploying and Querying
# **TODO:** Can you deploy your model to an endpoint and then query that endpoint to get a result?

# %%
# TODO: Deploy your model to an endpoint

# %%
# TODO: Run an prediction on the endpoint

# %%
# TODO: Remember to shutdown/delete your endpoint once your work is done

# %% [markdown]
# ### Cheaper Training and Cost Analysis
# **TODO:** Can you perform a cost analysis of your system and then use spot instances to lessen your model training cost?

# %%
# TODO: Cost Analysis

# %%
# TODO: Train your model using a spot instance

# %% [markdown]
# ### Multi-Instance Training
# **TODO:** Can you train your model on multiple instances?

# %%
# TODO: Train your model on Multiple Instances
